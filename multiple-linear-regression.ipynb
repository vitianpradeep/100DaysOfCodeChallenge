# %% [markdown]
# <a href="https://www.kaggle.com/code/pradeepdatascientist/multiple-linear-regression?scriptVersionId=121047304" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Multiple Linear Regression

# %% [markdown]
# ## Step 1: Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step 2: Load the CSV file

# %%
data = pd.read_csv('/kaggle/input/salary-data-with-age-and-experience/Salary_Data.csv')

# %% [markdown]
# ## Step 3: Explore the dataset¶

# %%
print(data.head())  # to view the
print(data.describe())  # to view the statistical summary of the data
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891
#        YearsExperience        Age         Salary
# count        30.000000  30.000000      30.000000
# mean          5.313333  27.216667   76003.000000
# std           2.837888   5.161267   27414.429785
# min           1.100000  21.000000   37731.000000
# 25%           3.200000  23.300000   56720.750000
# 50%           4.700000  25.000000   65237.000000
# 75%           7.700000  30.750000  100544.750000
# max          10.500000  38.000000  122391.000000

# %% [markdown]
# ## Step 4: Prepare the data for modeling

# %% [markdown]
# #### For multiple linear regression, we can select multiple features and one target variable.For the purpose of this example, let's assume we have a CSV file with two columns 'experience' and 'salary', and we want to perform linear regression to predict the salary based on the experience. We will use the 'experience' column as the feature and 'salary' column as the target.

# %%
# Multiple linear regression
X = data[['YearsExperience', 'Age']]
y = data['Salary'].values.reshape(-1, 1)

# %% [markdown]
# ## Step 5: Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Step 6: Create and train the linear regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 7: Make predictions and evaluate the model

# %%
# Predict the salary for the test data
y_pred = model.predict(X_test)

# Evaluate the model using mean squared error
mse = mean_squared_error(y_test, y_pred)
print('Mean squared error:', mse)
# Out:
# Mean squared error: 13242041.685624378

# %% [markdown]
# ## Step 8: Visualize the data and the model

# %%
# Multiple linear regression
plt.scatter(data['YearsExperience'], y)
plt.scatter(data['Age'], y)
plt.plot(data['YearsExperience'], model.predict(X), color='red')
plt.plot(data['Age'], model.predict(X), color='blue')
plt.xlabel('YearsExperience, Age')
plt.ylabel('Salary')
plt.show()
